# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("CombinedAllEvents_PET3.txt", sep="	|\t|\n",header=None, engine="python")
df
# Out:
#          0    1      2      3      4     5
# 0        1  0.0  240.2  -2.57 -11.00  3.77
# 1        1  0.0   88.8  -8.68  10.12  5.02
# 2        1  0.0  175.4 -10.78   6.68  3.44
# 3        2  0.0  246.7  -3.39   3.52  9.51
# 4        2  0.0   35.8  10.93  12.76  0.95
# ...     ..  ...    ...    ...    ...   ...
# 3439581  1  0.0  151.1  -8.60  -4.23  5.31
# 3439582  1  0.0  113.5   2.00   3.55  2.85
# 3439583  1  0.0  245.3  -6.82   3.02  9.28
# 3439584  1  0.0  107.1 -21.04 -16.24  7.47
# 3439585    NaN    NaN    NaN    NaN   NaN
#
# [3439586 rows x 6 columns]

# %%
plt.hist(df[2], bins=np.arange(0, 300.01,0.01), edgecolor='black')
plt.savefig("PET3draft.png",dpi=150)

# %%
plt.scatter(df[3], df[4])
plt.show()

# %%
N = 3439586
colors = np.random.rand(N)
plt.scatter(df[3], df[4], c=colors, alpha=0.5)
plt.show()
